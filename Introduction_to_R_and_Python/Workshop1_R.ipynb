# %% [markdown]
# ## Workshop: Jupyter
#
# This session is tailored for students using **R in Jupyter notebooks**.

# %% [markdown]
# ## 1. Creating, Editing, and Running Cells

# %% [markdown]
# 1.1 Creating a cell + shortcuts
#
# 1.2 Command mode vs edit mode

# %%
print("Hello world!")
# Out:
# [1] "Hello world!"

# %% [markdown]
# 1.3 Running a cell (`Hello world!`)
#
# 1.4 Deleting cells
#
# 1.5 Variables and running order of cells

# %%
a <- 10
b <- 5
a + b
# Out:
# [1] 15

# %% [markdown]
# 1.6 Interrupting or restarting kernel

# %%
Sys.sleep(3)  # Pauses execution for 3 seconds

# %% [markdown]
# ## 2. Markdown
#
# > You can use Markdown cells for **headings, bold text, LaTeX, HTML, bullet points**, etc.

# %% [markdown]
# # 1. Heading
# ## 2. Heading
# ### 3. Heading
#
# **bold text**
#
# <b>HTML bold</b>
# <h3>HTML heading</h3>
#
# $a^2$
#
# $\LaTeX$
#
# $\sum_{i=1}^{n} a_i$
#
# - bullet1
# - bullet2
# - bullet3
#
# 1. numbered1
# 2. numbered2
# 3. numbered3

# %% [markdown]
# ## 3. Menus

# %% [markdown]
# Restart kernel, clear output, shutdown, restart and run all (**important for homeworks**)

# %% [markdown]
# ## 4. Keyboard Shortcuts
#
# Useful resource: [Jupyter Notebook Tips & Shortcuts](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)

# %% [markdown]
# ## 5. [IPython Magics](https://ipython.readthedocs.io/en/8.31.0/interactive/magics.html) > Not for R 😢

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library(tidymodels)
# Out:
# Error in library(tidymodels): there is no package called ‘tidymodels’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
install.packages('tidymodels')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘listenv’, ‘parallelly’, ‘prodlim’, ‘future’, ‘warp’, ‘lhs’, ‘DiceDesign’, ‘sfd’, ‘sparsevctrs’, ‘patchwork’, ‘globals’, ‘clock’, ‘gower’, ‘ipred’, ‘timeDate’, ‘furrr’, ‘slider’, ‘GPfit’, ‘modelenv’, ‘dials’, ‘hardhat’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘recipes’, ‘rsample’, ‘tailor’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’

# %% [markdown]
# Option: Use Python runtime instead

# %%
%load_ext rpy2.ipython

# %%
%%R
install.packages('tidymodels')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘listenv’, ‘parallelly’, ‘prodlim’, ‘future’, ‘warp’, ‘lhs’, ‘DiceDesign’, ‘sfd’, ‘sparsevctrs’, ‘patchwork’, ‘globals’, ‘clock’, ‘gower’, ‘ipred’, ‘timeDate’, ‘furrr’, ‘slider’, ‘GPfit’, ‘modelenv’, ‘dials’, ‘hardhat’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘recipes’, ‘rsample’, ‘tailor’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’
#
# trying URL 'https://cran.rstudio.com/src/contrib/shape_1.4.6.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/future.apply_1.20.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/numDeriv_2016.8-1.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/progressr_0.15.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/SQUAREM_2021.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/diagram_1.6.5.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/lava_1.8.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.9.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/parallelly_1.45.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/prodlim_2025.04.28.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/future_1.67.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/warp_0.2.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/lhs_1.2.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/DiceDesign_1.10.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/sfd_0.1.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/sparsevctrs_0.3.4.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/patchwork_1.3.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/globals_0.18.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/clock_0.7.3.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/gower_1.0.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/ipred_0.9-15.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/timeDate_4041.110.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/furrr_0.3.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/slider_0.3.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/GPfit_1.0-9.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/modelenv_0.2.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/dials_1.4.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/hardhat_1.4.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/infer_1.0.9.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/modeldata_1.5.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/parsnip_1.3.3.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/recipes_1.3.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/rsample_1.3.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/tailor_0.1.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/tune_2.0.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/workflows_1.3.0.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/workflowsets_1.1.1.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/yardstick_1.3.2.tar.gz'
# trying URL 'https://cran.rstudio.com/src/contrib/tidymodels_1.4.0.tar.gz'
#
# The downloaded source packages are in
# 	‘/tmp/Rtmp4E3qXd/downloaded_packages’

# %%
%%R
library(tidymodels)
# Out:
# ── Attaching packages ────────────────────────────────────── tidymodels 1.4.0 ──
# ✔ broom        1.0.9     ✔ recipes      1.3.1
# ✔ dials        1.4.2     ✔ rsample      1.3.1
# ✔ dplyr        1.1.4     ✔ tibble       3.3.0
# ✔ ggplot2      3.5.2     ✔ tidyr        1.3.1
# ✔ infer        1.0.9     ✔ tune         2.0.0
# ✔ modeldata    1.5.1     ✔ workflows    1.3.0
# ✔ parsnip      1.3.3     ✔ workflowsets 1.1.1
# ✔ purrr        1.1.0     ✔ yardstick    1.3.2
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ purrr::discard() masks scales::discard()
# ✖ dplyr::filter()  masks stats::filter()
# ✖ dplyr::lag()     masks stats::lag()
# ✖ recipes::step()  masks stats::step()
# • Learn how to get started at https://www.tidymodels.org/start/

# %%
%alias
# Out:
# Total number of aliases: 12
# [('cat', 'cat'),
#  ('cp', 'cp'),
#  ('ldir', 'ls -F -o --color %l | grep /$'),
#  ('lf', 'ls -F -o --color %l | grep ^-'),
#  ('lk', 'ls -F -o --color %l | grep ^l'),
#  ('ll', 'ls -F -o --color'),
#  ('ls', 'ls -F --color'),
#  ('lx', 'ls -F -o --color %l | grep ^-..x'),
#  ('mkdir', 'mkdir'),
#  ('mv', 'mv'),
#  ('rm', 'rm'),
#  ('rmdir', 'rmdir')]

# %% [markdown]
# ## 6. Shell Commands

# %%
# List directory contents
!dir    # Windows
!ls     # Linux/macOS
# Out:
# sample_data
# sample_data
